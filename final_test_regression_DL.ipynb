# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
dataset = pd.read_csv("C:/Users/UserName/Desktop/인공지능 개론/데이터 셋/mushrooms.csv")
dataset
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
dataset.shape
# Out:
# (8124, 23)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in dataset.columns:
    dataset[i]=le.fit_transform(dataset[i])
dataset
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# 2                   1             0          0           5  ...
# 3                   1             0          1           5  ...
# 4                   1             1          0           4  ...
# ...               ...           ...        ...         ...  ...
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            2                       7
# 1                            2                       7
# 2                            2                       7
# 3                            2                       7
# 4                            2                       7
# ...                        ...                     ...
# 8119                         2                       5
# 8120                         2                       5
# 8121                         2                       5
# 8122                         1                       7
# 8123                         2                       5
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          7          0           2            1          4
# 1                          7          0           2            1          4
# 2                          7          0           2            1          4
# 3                          7          0           2            1          4
# 4                          7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 8119                       5          0           1            1          4
# 8120                       5          0           0            1          4
# 8121                       5          0           1            1          4
# 8122                       7          0           2            1          0
# 8123                       5          0           1            1          4
#
#       spore-print-color  population  habitat
# 0                     2           3        5
# 1                     3           2        1
# 2                     3           2        3
# 3                     2           3        5
# 4                     3           0        1
# ...                 ...         ...      ...
# 8119                  0           1        2
# 8120                  0           4        2
# 8121                  0           1        2
# 8122                  7           4        2
# 8123                  4           1        2
#
# [8124 rows x 23 columns]

# %%
dataset = dataset.sample(frac = 0.1)

# %%
dataset.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
sns.countplot(data = dataset, x="class")
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Label")
# Out:
# Text(0.5, 1.0, 'Label')

# %%
dataset
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 5970      0          5            3          6        0     5
# 6299      1          5            2          4        0     8
# 1937      0          5            0          8        0     5
# 1570      0          2            0          4        0     5
# 983       0          5            0          4        0     5
# ...     ...        ...          ...        ...      ...   ...
# 466       0          5            2          8        1     0
# 6586      1          3            3          4        0     8
# 5232      1          5            3          9        0     2
# 7047      1          2            3          2        0     7
# 1715      0          5            0          3        1     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 5970                1             0          1           9  ...
# 6299                1             0          1           0  ...
# 1937                1             1          0           3  ...
# 1570                1             1          0           4  ...
# 983                 1             1          0           4  ...
# ...               ...           ...        ...         ...  ...
# 466                 1             0          0           2  ...
# 6586                1             0          1           0  ...
# 5232                1             0          0           3  ...
# 7047                1             0          1           0  ...
# 1715                1             0          0           9  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 5970                         0                       7
# 6299                         1                       7
# 1937                         2                       7
# 1570                         0                       7
# 983                          2                       7
# ...                        ...                     ...
# 466                          2                       7
# 6586                         1                       7
# 5232                         1                       0
# 7047                         1                       7
# 1715                         2                       6
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 5970                       7          0           2            1          1
# 6299                       7          0           2            1          0
# 1937                       7          0           2            1          0
# 1570                       7          0           2            1          0
# 983                        7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 466                        7          0           2            1          4
# 6586                       6          0           2            1          0
# 5232                       4          0           2            1          2
# 7047                       6          0           2            1          0
# 1715                       6          0           2            1          4
#
#       spore-print-color  population  habitat
# 5970                  1           5        0
# 6299                  7           4        4
# 1937                  3           0        1
# 1570                  2           0        1
# 983                   3           3        1
# ...                 ...         ...      ...
# 466                   2           2        3
# 6586                  7           4        4
# 5232                  1           4        1
# 7047                  7           4        0
# 1715                  2           5        0
#
# [812 rows x 23 columns]

# %%
data = dataset.drop(['class'], axis = 1)
data
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 5970          5            3          6        0     5                1
# 6299          5            2          4        0     8                1
# 1937          5            0          8        0     5                1
# 1570          2            0          4        0     5                1
# 983           5            0          4        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 466           5            2          8        1     0                1
# 6586          3            3          4        0     8                1
# 5232          5            3          9        0     2                1
# 7047          2            3          2        0     7                1
# 1715          5            0          3        1     5                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 5970             0          1           9            0  ...
# 6299             0          1           0            1  ...
# 1937             1          0           3            1  ...
# 1570             1          0           4            1  ...
# 983              1          0           4            1  ...
# ...            ...        ...         ...          ...  ...
# 466              0          0           2            0  ...
# 6586             0          1           0            1  ...
# 5232             0          0           3            0  ...
# 7047             0          1           0            1  ...
# 1715             0          0           9            1  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 5970                         0                       7
# 6299                         1                       7
# 1937                         2                       7
# 1570                         0                       7
# 983                          2                       7
# ...                        ...                     ...
# 466                          2                       7
# 6586                         1                       7
# 5232                         1                       0
# 7047                         1                       7
# 1715                         2                       6
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 5970                       7          0           2            1          1
# 6299                       7          0           2            1          0
# 1937                       7          0           2            1          0
# 1570                       7          0           2            1          0
# 983                        7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 466                        7          0           2            1          4
# 6586                       6          0           2            1          0
# 5232                       4          0           2            1          2
# 7047                       6          0           2            1          0
# 1715                       6          0           2            1          4
#
#       spore-print-color  population  habitat
# 5970                  1           5        0
# 6299                  7           4        4
# 1937                  3           0        1
# 1570                  2           0        1
# 983                   3           3        1
# ...                 ...         ...      ...
# 466                   2           2        3
# 6586                  7           4        4
# 5232                  1           4        1
# 7047                  7           4        0
# 1715                  2           5        0
#
# [812 rows x 22 columns]

# %%
df_corr = data.corr()
#히트맵, 차원을 줄이기 위해서 숫자가 큰 column 4개만 넣어보자!
plt.figure(figsize=(10, 10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

x_data=data.loc[:, ['cap-shape', 'cap-surface', 'cap-color', 'gill-attachment', 'gill-spacing']]
y_data=data.loc[:, 'gill-size']
X_train, X_test, y_train, y_test=train_test_split(x_data,
                                                  y_data,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (649, 5) (649,)
# (163, 5) (163,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(64, activation = 'relu', input_shape = (5,)))
model.add(Dense(128, activation = 'relu'))
model.add(Dense(256, activation = 'relu'))
model.add(Dense(1)) 
model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                384
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 41,985
# Trainable params: 41,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
N_EPOCHS = 20
history = model.fit(X_train, y_train, epochs = N_EPOCHS, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1844 - mse: 0.1844 - val_loss: 0.1537 - val_mse: 0.1537
# Epoch 2/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1762 - mse: 0.1762 - val_loss: 0.2113 - val_mse: 0.2113
# Epoch 3/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1624 - mse: 0.1624 - val_loss: 0.1798 - val_mse: 0.1798
# Epoch 4/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1683 - mse: 0.1683 - val_loss: 0.1776 - val_mse: 0.1776
# Epoch 5/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1601 - mse: 0.1601 - val_loss: 0.1550 - val_mse: 0.1550
# Epoch 6/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1660 - mse: 0.1660 - val_loss: 0.1920 - val_mse: 0.1920
# Epoch 7/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1510 - mse: 0.1510 - val_loss: 0.1271 - val_mse: 0.1271
# Epoch 8/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1507 - mse: 0.1507 - val_loss: 0.1897 - val_mse: 0.1897
# Epoch 9/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1519 - mse: 0.1519 - val_loss: 0.1204 - val_mse: 0.1204
# Epoch 10/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1452 - mse: 0.1452 - val_loss: 0.1248 - val_mse: 0.1248
# Epoch 11/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1511 - mse: 0.1511 - val_loss: 0.1673 - val_mse: 0.1673
# Epoch 12/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1506 - mse: 0.1506 - val_loss: 0.1244 - val_mse: 0.1244
# Epoch 13/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1471 - mse: 0.1471 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 14/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1462 - mse: 0.1462 - val_loss: 0.1126 - val_mse: 0.1126
# Epoch 15/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1433 - mse: 0.1433 - val_loss: 0.1254 - val_mse: 0.1254
# Epoch 16/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1443 - mse: 0.1443 - val_loss: 0.1189 - val_mse: 0.1189
# Epoch 17/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1358 - mse: 0.1358 - val_loss: 0.1603 - val_mse: 0.1603
# Epoch 18/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1449 - mse: 0.1449 - val_loss: 0.1412 - val_mse: 0.1412
# Epoch 19/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1390 - mse: 0.1390 - val_loss: 0.1277 - val_mse: 0.1277
# Epoch 20/20
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1396 - mse: 0.1396 - val_loss: 0.1336 - val_mse: 0.1336

# %%
model.fit(X_train, y_train, epochs=80, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 0s 997us/step - loss: 0.1080 - mse: 0.1080

# %%
model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1336 - mse: 0.1336
# [0.13363078236579895, 0.13363078236579895]

# %%
# loss 체크
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
